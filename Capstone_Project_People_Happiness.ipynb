# %% [markdown]
# <a href="https://colab.research.google.com/github/eggtart-42/git_test/blob/main/Capstone_Project_People_Happiness.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Capstone Project: What makes people happy?
#
# Congratulations for making it this far in the course! You absolutely rock and should be very proud of yourself! :)
# In this project, you will put into practice everything you've learned in the past units and go through the whole process of data analysis.
#
# The data you will work for this project comes from the `World Happiness Report`. The `World Happiness Report` is a landmark survey of the state of global happiness that ranks 156 countries by how happy their citizens perceive themselves to be. Over the last years, `World Happiness Report` focuses on happiness and the community: how happiness has evolved over the past dozen years, with a focus on the technologies, social norms, conflicts and government policies that have driven those changes.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Dataset information**
# >dataset: `Dataset-Happiness_Score.csv`
#
# The information in the datasets is based on the answers of survey participants who were asked to evaluate how satisfied they are with their current lives on a scale from 0 to 10 (the most excellent conceivable life being 10 and the most exceedingly bad conceivable life being 0).
#
# The Happiness Score is explained by the following factors:
#
# - `Overall rank`: Rank of a country on the happiness scale when compared to other countries
# - `Country or region`
# - `Score`:  National average of the responses to the main life happiness evaluation question asked in the survey. The range is [0-10]
# - `GDP per capita`: Measure of the standard of living, prosperity, and overall well-being in a country; the higher, the better.
# - `Healthy Life Expectancy`: The score range is [0-1]. The higher this value, the more confidence people have in terms of healthy life expectancy
# - `Social support`: It indicates how much people appreciate the social support from their governments. Ranges from [0-2]; the higher this value, the more appreciation they have.
# - `Freedom to make life choices`: Ranges from 0 to 1. The higher this value, the more free people feel
# - `Generosity`: Ranges from 0 to 1. The higher this value, the more generous people feel
# - `Perceptions of corruption`: Perception of corruption in a country; ranges from 0 to 1. The higher this value, the lower the perception of corruption
# - `year`: the year the data was collected

# %% [markdown]
# **Project Objective**
#
# Tell a story with your dataset, and to try to answer the following question:
#
# >`Which factors are more/the most important to live a happier life?`
#
# The results of your analysis could help people and their countries/governments to focus their resources and investments on the more significant factors to achieve a higher level of happiness.

# %% [markdown]
# **Project Pointers**
# You are expected to:
# - Conduct data cleaning (deal with duplicates, missing data, incorrect/inconsistent formatting, outliers, etc.)
# - Conduct univariate analysis
# - Conduct bivariate analysis
# - Write out a conclusion based on your analysis that answers the project question and, ideally, makes recommendations about what actions people/countries can take.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fa4686b6-f9e8-4a1a-8099-4576efc556d2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fa4686b6-f9e8-4a1a-8099-4576efc556d2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
happiness_data = pd.read_csv('Data-Happiness_Score.csv')

# %%
happiness_data.head(10)
# Out:
#    Unnamed: 0.1  Unnamed: 0  Overall rank Country or region  Score  \
# 0             0           0             1           Finland  7.632
# 1             1           1             2            Norway  7.594
# 2             2           2             3           Denmark  7.555
# 3             3           3             4           Iceland  7.495
# 4             4           4             5       Switzerland  7.487
# 5             5           5             6       Netherlands  7.441
# 6             6           6             7            Canada  7.328
# 7             7           7             8       New Zealand  7.324
# 8             8           8             9            Sweden  7.314
# 9             9           9            10         Australia  7.272
#
#    GDP per capita  Social support  Healthy life expectancy  \
# 0           1.305           1.592                      NaN
# 1           1.456           1.582                      NaN
# ...

# %%
happiness_data.shape
# Out:
# (312, 12)

# %%
happiness_data.drop("Unnamed: 0", axis=1, inplace=True)

# %%
happiness_data.drop("Unnamed: 0.1", axis=1, inplace=True)

# %%
happiness_data.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                      NaN                         0.681       0.202
# 1                      NaN                         0.686       0.286
# 2                      NaN                         0.683       0.284
# 3                      NaN                         0.677       0.353
# 4                      NaN                         0.660       0.256
#
#    Perceptions of corruption  year
# 0                      0.393  2018
# 1                      0.340  2018
# ...

# %%
happiness_data['Healthy life expectancy'].value_counts()
# Out:
# 0.000    2
# 0.048    1
# 0.080    1
# 0.053    1
# 0.079    1
# 0.010    1
# Name: Healthy life expectancy, dtype: int64

# %% [markdown]
# There are only 7 data points for Healthy life expentacy for 312 rows. 97.8% of values are missing. This column should be deleted because it is incomplete.

# %%
happiness_data.drop("Healthy life expectancy", axis=1, inplace=True)

# %%
happiness_data.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  year
# 0                         0.681       0.202                      0.393  2018
# 1                         0.686       0.286                      0.340  2018
# 2                         0.683       0.284                      0.408  2018
# 3                         0.677       0.353                      0.138  2018
# 4                         0.660       0.256                      0.357  2018

# %%
happiness_data['Country or region'].value_counts()
# Out:
# Finland        2
# Ivory Coast    2
# Bulgaria       2
# Nepal          2
# Venezuela      2
#               ..
# Sudan          1
# Belize         1
# Macedonia      1
# Angola         1
# Comoros        1
# Name: Country or region, Length: 160, dtype: int64

# %%
happiness_data[happiness_data['Country or region']=="Finland"]
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 0               1           Finland  7.632           1.305           1.592
# 156             1           Finland  7.769           1.340           1.587
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  year
# 0                           0.681       0.202                      0.393  2018
# 156                         0.596       0.153                      0.393  2019

# %%
happiness_data['year'].value_counts()
# Out:
# 2018    156
# 2019    156
# Name: year, dtype: int64

# %%
happiness_2019 = happiness_data[happiness_data['year']==2019]

# %%
happiness_2018 = happiness_data[happiness_data['year']==2018]

# %%
happiness_2018.head(10)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
# 5             6       Netherlands  7.441           1.361           1.488
# 6             7            Canada  7.328           1.330           1.532
# 7             8       New Zealand  7.324           1.268           1.601
# 8             9            Sweden  7.314           1.355           1.501
# 9            10         Australia  7.272           1.340           1.573
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  year
# 0                         0.681       0.202                      0.393  2018
# ...

# %%
happiness_2019.head(10)
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 156             1           Finland  7.769           1.340           1.587
# 157             2           Denmark  7.600           1.383           1.573
# 158             3            Norway  7.554           1.488           1.582
# 159             4           Iceland  7.494           1.380           1.624
# 160             5       Netherlands  7.488           1.396           1.522
# 161             6       Switzerland  7.480           1.452           1.526
# 162             7            Sweden  7.343           1.387           1.487
# 163             8       New Zealand  7.307           1.303           1.557
# 164             9            Canada  7.278           1.365           1.505
# 165            10           Austria  7.246           1.376           1.475
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  year
# ...

# %%
happiness_2019.isna().sum()
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# year                            0
# dtype: int64

# %%
happiness_2018.isna().sum()
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       1
# year                            0
# dtype: int64

# %% [markdown]
# Decided to use 2019 data because it is the most recent and there is a different in ranking between 2018 and 2019.

# %%
happiness_2019['Country or region'].value_counts()
# Out:
# Finland                1
# Venezuela              1
# Jordan                 1
# Benin                  1
# Congo (Brazzaville)    1
#                       ..
# Latvia                 1
# South Korea            1
# Estonia                1
# Jamaica                1
# South Sudan            1
# Name: Country or region, Length: 156, dtype: int64

# %% [markdown]
# Verifying there are no further country duplicates in 2019

# %%
happiness_2019.duplicated().sum()
# Out:
# 0

# %%
happiness_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 156 entries, 156 to 311
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Freedom to make life choices  156 non-null    float64
#  6   Generosity                    156 non-null    float64
#  7   Perceptions of corruption     156 non-null    float64
#  8   year                          156 non-null    int64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 12.2+ KB

# %%
happiness_2019.describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.407096        0.905147        1.208814
# std       45.177428    1.113120        0.398389        0.299191
# min        1.000000    2.853000        0.000000        0.000000
# 25%       39.750000    4.544500        0.602750        1.055750
# 50%       78.500000    5.379500        0.960000        1.271500
# 75%      117.250000    6.184500        1.232500        1.452500
# max      156.000000    7.769000        1.684000        1.624000
#
#        Freedom to make life choices  Generosity  Perceptions of corruption  \
# count                    156.000000  156.000000                 156.000000
# mean                       0.392571    0.184846                   0.110603
# std                        0.143289    0.095254                   0.094538
# min                        0.000000    0.000000                   0.000000
# ...

# %%
happiness_2019[happiness_2019['GDP per capita']==0]
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 267           112           Somalia  4.668             0.0           0.698
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  year
# 267                         0.559       0.243                       0.27  2019

# %%
happiness_2019[happiness_2019['Social support']==0]
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 310           155  Central African Republic  3.083           0.026
#
#      Social support  Freedom to make life choices  Generosity  \
# 310             0.0                         0.225       0.235
#
#      Perceptions of corruption  year
# 310                      0.035  2019

# %%
happiness_2019[happiness_2019['Freedom to make life choices']==0]
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 309           154       Afghanistan  3.203            0.35           0.517
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  year
# 309                           0.0       0.158                      0.025  2019

# %%
happiness_2019[happiness_2019['Generosity']==0]
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 237            82            Greece  5.287           1.181           1.156
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  year
# 237                         0.067         0.0                      0.034  2019

# %%
happiness_2019[happiness_2019['Perceptions of corruption']==0]
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 226            71           Moldova  5.529           0.685           1.328
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  year
# 226                         0.245       0.181                        0.0  2019

# %%
happiness_clean = happiness_2019[happiness_2019['GDP per capita']>0]

# %% [markdown]
# There is no way GDP can be 0, so I am removing that value.

# %%
happiness_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 155 entries, 156 to 311
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  155 non-null    int64
#  1   Country or region             155 non-null    object
#  2   Score                         155 non-null    float64
#  3   GDP per capita                155 non-null    float64
#  4   Social support                155 non-null    float64
#  5   Freedom to make life choices  155 non-null    float64
#  6   Generosity                    155 non-null    float64
#  7   Perceptions of corruption     155 non-null    float64
#  8   year                          155 non-null    int64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 12.1+ KB

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
plt.figure(figsize = (20,10))
plt.title('Boxplots of Numerical Variables')
happiness_clean[['Country or region','Perceptions of corruption','Generosity','Freedom to make life choices','Social support','GDP per capita','Score']].boxplot(vert=False)

plt.show()

# %%
happiness_clean.skew()
# Out:
# <ipython-input-35-003779f54558>:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   happiness_clean.skew()
# Overall rank                    0.011848
# Score                           0.000382
# GDP per capita                 -0.368925
# Social support                 -1.164373
# Freedom to make life choices   -0.680100
# Generosity                      0.756760
# Perceptions of corruption       1.692994
# year                            0.000000
# dtype: float64

# %% [markdown]
# Social support and perception of corruption is highly skewed. Freedom to make life choices and Generosity is moderately skewed. The rest are symetrical.

# %%
happiness_clean.kurtosis()
# Out:
# <ipython-input-36-c5c5485c39ca>:1: FutureWarning: The default value of numeric_only in DataFrame.kurt is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   happiness_clean.kurtosis()
# Overall rank                   -1.200594
# Score                          -0.611382
# GDP per capita                 -0.792956
# Social support                  1.361419
# Freedom to make life choices   -0.068679
# Generosity                      1.178171
# Perceptions of corruption       2.608491
# year                            0.000000
# dtype: float64

# %% [markdown]
# There isn't much skew for most except soocial support, generosity and perceptions of corruption all over 1 - very skewed. Using IQR for skewed variables to remove any outliers.

# %% [markdown]
# Analysis of outliers using IQR and SD:

# %%
# making a copy of the original dataframe
data_IQR = happiness_clean.copy()

# calculate the 1st quartile for multiple columns
Q1 = data_IQR[['Social support', 'Perceptions of corruption', 'Freedom to make life choices','Generosity']].quantile(0.25)

# calculate the 3rd quartile for multiple columns
Q3 = data_IQR[['Social support', 'Perceptions of corruption', 'Freedom to make life choices', 'Generosity']].quantile(0.75)

# calculate the IQR (difference between Q3 and Q1) for multiple columns
IQR = Q3 - Q1

# calculate the lower and upper limits for multiple columns
lower_limit = (Q1 - 1.5 * IQR)
upper_limit = (Q3 + 1.5 * IQR)

# select only those rows from the dataset that are within the lower and upper limits for multiple columns
data_IQR = data_IQR[
    (data_IQR['Social support'] > lower_limit['Social support']) &
    (data_IQR['Social support'] < upper_limit['Social support']) &
    (data_IQR['Perceptions of corruption'] > lower_limit['Perceptions of corruption']) &
    (data_IQR['Perceptions of corruption'] < upper_limit['Perceptions of corruption']) &
    (data_IQR['Generosity'] > lower_limit['Generosity']) &
    (data_IQR['Generosity'] < upper_limit['Generosity']) &
    (data_IQR['Freedom to make life choices'] > lower_limit['Freedom to make life choices']) &
    (data_IQR['Freedom to make life choices'] < upper_limit['Freedom to make life choices'])
]

# %%
plt.figure(figsize = (20,5))
plt.title('Test')

# bins specifies how many buckets we are categorizing our data into
data_IQR["Social support"].plot.hist()

plt.show()

# %%
plt.figure(figsize = (20,5))
plt.title('Test')

# bins specifies how many buckets we are categorizing our data into
data_IQR["Perceptions of corruption"].plot.hist()

plt.show()

# %%
plt.figure(figsize = (20,5))
plt.title('Test')

# bins specifies how many buckets we are categorizing our data into
data_IQR["Freedom to make life choices"].plot.hist()

plt.show()

# %%
plt.figure(figsize = (20,5))
plt.title('Test')

# bins specifies how many buckets we are categorizing our data into
data_IQR["Generosity"].plot.hist()

plt.show()

# %%
data_IQR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 133 entries, 159 to 308
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  133 non-null    int64
#  1   Country or region             133 non-null    object
#  2   Score                         133 non-null    float64
#  3   GDP per capita                133 non-null    float64
#  4   Social support                133 non-null    float64
#  5   Freedom to make life choices  133 non-null    float64
#  6   Generosity                    133 non-null    float64
#  7   Perceptions of corruption     133 non-null    float64
#  8   year                          133 non-null    int64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 10.4+ KB

# %%
happiness_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 155 entries, 156 to 311
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  155 non-null    int64
#  1   Country or region             155 non-null    object
#  2   Score                         155 non-null    float64
#  3   GDP per capita                155 non-null    float64
#  4   Social support                155 non-null    float64
#  5   Freedom to make life choices  155 non-null    float64
#  6   Generosity                    155 non-null    float64
#  7   Perceptions of corruption     155 non-null    float64
#  8   year                          155 non-null    int64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 12.1+ KB

# %%
data_IQR.describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    133.000000  133.000000      133.000000      133.000000
# mean      80.496241    5.352211        0.893677        1.223827
# std       40.928545    0.946258        0.361088        0.243892
# min        4.000000    3.231000        0.073000        0.560000
# 25%       46.000000    4.559000        0.642000        1.069000
# 50%       80.000000    5.339000        0.960000        1.266000
# 75%      116.000000    6.100000        1.183000        1.432000
# max      153.000000    7.494000        1.684000        1.624000
#
#        Freedom to make life choices  Generosity  Perceptions of corruption  \
# count                    133.000000  133.000000                 133.000000
# mean                       0.383729    0.169466                   0.085090
# std                        0.129279    0.086123                   0.054913
# min                        0.026000    0.000000                   0.000000
# ...

# %%
happiness_clean.describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    155.000000  155.000000      155.000000      155.000000
# mean      78.283871    5.411865        0.910987        1.212110
# std       45.242888    1.115128        0.392925        0.297307
# min        1.000000    2.853000        0.026000        0.000000
# 25%       39.500000    4.541000        0.615000        1.057000
# 50%       78.000000    5.386000        0.960000        1.274000
# 75%      117.500000    6.187000        1.234000        1.453000
# max      156.000000    7.769000        1.684000        1.624000
#
#        Freedom to make life choices  Generosity  Perceptions of corruption  \
# count                    155.000000  155.000000                 155.000000
# mean                       0.391497    0.184471                   0.109574
# std                        0.143123    0.095447                   0.093965
# min                        0.000000    0.000000                   0.000000
# ...

# %%
data_SD = data_IQR.copy()

data_SD = data_SD[(stats.zscore(data_SD[['GDP per capita', 'Score']]) < 3) & (stats.zscore(data_SD[['GDP per capita', 'Score']]) > -3)]

# %%
plt.figure(figsize = (20,5))
plt.title('Histogram of GDP per capita without Outliers')

# bins specifies how many buckets we are categorizing our data into
data_SD["GDP per capita"].plot.hist(bins=50)

plt.show()

# %%
plt.figure(figsize = (20,5))
plt.title('Histogram of Score without Outliers')

# bins specifies how many buckets we are categorizing our data into
data_SD["Score"].plot.hist(bins=50)

plt.show()

# %%
data_IQR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 133 entries, 159 to 308
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  133 non-null    int64
#  1   Country or region             133 non-null    object
#  2   Score                         133 non-null    float64
#  3   GDP per capita                133 non-null    float64
#  4   Social support                133 non-null    float64
#  5   Freedom to make life choices  133 non-null    float64
#  6   Generosity                    133 non-null    float64
#  7   Perceptions of corruption     133 non-null    float64
#  8   year                          133 non-null    int64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 10.4+ KB

# %%
data_SD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 133 entries, 159 to 308
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  0 non-null      float64
#  1   Country or region             0 non-null      object
#  2   Score                         133 non-null    float64
#  3   GDP per capita                133 non-null    float64
#  4   Social support                0 non-null      float64
#  5   Freedom to make life choices  0 non-null      float64
#  6   Generosity                    0 non-null      float64
#  7   Perceptions of corruption     0 non-null      float64
#  8   year                          0 non-null      float64
# dtypes: float64(8), object(1)
# memory usage: 10.4+ KB

# %% [markdown]
# No outliers removed for the normally distributed variables - can use Data_IQR

# %%
data_IQR.head()
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 159             4           Iceland  7.494           1.380           1.624
# 165            10           Austria  7.246           1.376           1.475
# 167            12        Costa Rica  7.167           1.034           1.441
# 168            13            Israel  7.139           1.276           1.455
# 170            15    United Kingdom  7.054           1.333           1.538
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  year
# 159                         0.591       0.354                      0.118  2019
# 165                         0.532       0.244                      0.226  2019
# 167                         0.558       0.144                      0.093  2019
# 168                         0.371       0.261                      0.082  2019
# 170                         0.450       0.348                      0.278  2019

# %%
happiness_clean.head()
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 156             1           Finland  7.769           1.340           1.587
# 157             2           Denmark  7.600           1.383           1.573
# 158             3            Norway  7.554           1.488           1.582
# 159             4           Iceland  7.494           1.380           1.624
# 160             5       Netherlands  7.488           1.396           1.522
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  year
# 156                         0.596       0.153                      0.393  2019
# 157                         0.592       0.252                      0.410  2019
# 158                         0.603       0.271                      0.341  2019
# 159                         0.591       0.354                      0.118  2019
# 160                         0.557       0.322                      0.298  2019

# %% [markdown]
# Removing of outliers using IQR on skewed variables removed the top results - not suitable to remove these outliers. This suggests that outlier variables are meaningful to the overall score and we can't remove them.

# %%
happiness_clean.plot.scatter(x='Score', y='Social support')
# Out:
# <Axes: xlabel='Score', ylabel='Social support'>

# %%
data_IQR.plot.hexbin(x='Score', y='Social support', gridsize=10)
# Out:
# <Axes: xlabel='Score', ylabel='Social support'>

# %%
happiness_clean.plot.scatter(x='Score', y='Generosity')
# Out:
# <Axes: xlabel='Score', ylabel='Generosity'>

# %%
happiness_clean.plot.scatter(x='Score', y='Freedom to make life choices')
# Out:
# <Axes: xlabel='Score', ylabel='Freedom to make life choices'>

# %%
data_IQR.plot.hexbin(x='Score', y='Freedom to make life choices', gridsize=10)
# Out:
# <Axes: xlabel='Score', ylabel='Freedom to make life choices'>

# %%
happiness_clean.plot.scatter(x='Score', y='Perceptions of corruption')
# Out:
# <Axes: xlabel='Score', ylabel='Perceptions of corruption'>

# %%
data_IQR.plot.hexbin(x='Score', y='Perceptions of corruption', gridsize=10)
# Out:
# <Axes: xlabel='Score', ylabel='Perceptions of corruption'>

# %%
happiness_clean.plot.scatter(x='Score', y='GDP per capita')
# Out:
# <Axes: xlabel='Score', ylabel='GDP per capita'>

# %%
corr = happiness_clean.corr()
corr
# Out:
# <ipython-input-61-67ef20750523>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = happiness_clean.corr()
#                               Overall rank     Score  GDP per capita  \
# Overall rank                      1.000000 -0.989081       -0.806047
# Score                            -0.989081  1.000000        0.798712
# GDP per capita                   -0.806047  0.798712        1.000000
# Social support                   -0.767906  0.778201        0.749390
# Freedom to make life choices     -0.555626  0.575094        0.404803
# Generosity                       -0.051085  0.078664       -0.071957
# Perceptions of corruption        -0.364097  0.397128        0.332443
# year                                   NaN       NaN             NaN
#
# ...

# %% [markdown]
# Closely correlated -

# %% [markdown]
# *   Rank/Score and GDP per capita
# *   Rank/Score and Social support

# %% [markdown]
# Somewhat correlated -
#
#
#
# *   Rank/Score and Freedom to make life choices (about 0.6)
# *   Rank/Score and Perceptions of corruption (about 0.4)

# %%
import seaborn as sns

# %%
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
# Select the numerical variables of interest (excluding 'Score')
numerical_variables = ['GDP per capita', 'Social support', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption']

# Create a subset of the data with only the numerical variables
numerical_data = happiness_clean[numerical_variables + ['Score']]

# Calculate the correlation matrix
correlation_matrix = numerical_data.corr()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='RdBu_r', vmin=-1, vmax=1)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("ticks")

# Smallest context:
sns.set_context("paper")

variables = ['GDP per capita', 'Social support', 'Freedom to make life choices','Perceptions of corruption']

# Create separate scatter plots for each variable
for variable in variables:
    plt.figure()
    sns.regplot(x=variable, y='Score', data=happiness_clean, scatter_kws={"color": "orange"}, line_kws={"color": "lightblue"})
    plt.xlabel(variable)
    plt.ylabel('Score')
    plt.title(f'Scatter Plot of {variable} vs. Score')
    plt.ylim(bottom=0)

plt.show()

# %% [markdown]
# Other than GDP per capita, appreciation of social support is the most correlated to a high happiness score. 2 is the highest value for appeciation of social support - the top ten highest scores have a appreciation of social support higher than 1.4. (find average GDP? how do you "account for GDP" and focus on social support)
#
# GDP and Social Support are also correlated, as high GDP countries can often provide more social services. - point out USA?

# %%
happiness_clean10 = happiness_clean.head(10)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.relplot(
    data=happiness_clean10, kind="scatter",
    x="Social support", y="Score", hue="Country or region",
size="GDP per capita", sizes=(10, 200))

plt.show()

# %%
bottom30 = happiness_clean[happiness_clean[
'Overall rank']>124]

# %%
bottom30.head(30)
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 280           125        Bangladesh  4.456           0.562           0.928
# 281           126              Iraq  4.437           1.043           0.980
# 282           127  Congo (Kinshasa)  4.418           0.094           1.125
# 283           128              Mali  4.390           0.385           1.105
# 284           129      Sierra Leone  4.374           0.268           0.841
# 285           130         Sri Lanka  4.366           0.949           1.265
# 286           131           Myanmar  4.360           0.710           1.181
# 287           132              Chad  4.350           0.350           0.766
# 288           133           Ukraine  4.332           0.820           1.390
# 289           134          Ethiopia  4.286           0.336           1.033
# 290           135         Swaziland  4.212           0.811           1.149
# ...

# %%
bottom30.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32 entries, 280 to 311
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  32 non-null     int64
#  1   Country or region             32 non-null     object
#  2   Score                         32 non-null     float64
#  3   GDP per capita                32 non-null     float64
#  4   Social support                32 non-null     float64
#  5   Freedom to make life choices  32 non-null     float64
#  6   Generosity                    32 non-null     float64
#  7   Perceptions of corruption     32 non-null     float64
#  8   year                          32 non-null     int64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 2.5+ KB

# %%
sns.relplot(
    data=bottom10, kind="scatter",
    x="Social support", y="Score", hue="Country or region",
size="GDP per capita", sizes=(10, 200))

plt.show()

# %%
# Select the numerical variables of interest (excluding 'Score')
numerical_variables = ['GDP per capita', 'Social support', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption']

# Create a subset of the data with only the numerical variables
numerical_data = bottom10[numerical_variables + ['Score']]

# Calculate the correlation matrix
correlation_matrix10 = numerical_data.corr()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix10, annot=True, cmap='RdBu_r', vmin=-1, vmax=1)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
# Select the numerical variables of interest (excluding 'Score')
numerical_variables = ['GDP per capita', 'Social support', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption']

# Create a subset of the data with only the numerical variables
numerical_data = happiness_clean10[numerical_variables + ['Score']]

# Calculate the correlation matrix
correlation_matrixtop10 = numerical_data.corr()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrixtop10, annot=True, cmap='RdBu_r', vmin=-1, vmax=1)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# The correlation matrixes for the top 10 ranked happiest countries and the bottom ten ranked happiest countries look very different.
#
# Overall, there appears to be a much stronger correlation between social support and happiness score for the top ten happiest countries. There is a strong correlation (>0.6). It is noteable that Freedom to make life choices and Generosity are both also moderately correlated with score.
#
# For the bottom 10 countries, there is a weak correlation between social support and happiness score (weak corelation,  0.20 – 0.39). All variables have weak or minimal correlation to happiness score. Interestinly, GDP had minimal correlation. This suggests that there is a missing variable that impacts happiness in the bottom 10 to a much greater extend. This could be life expectancy (removed due a lack of complete data).
#
# Social support nonetheless had the highest correlation to Score for both the top 10 and bottom 10 ranked countries.
